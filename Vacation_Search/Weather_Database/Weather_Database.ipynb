# %%
# Import the dependencies
import requests
import numpy as np
import random
from citipy import citipy
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the datetime module from the datetime library.

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9fe74a075ae894a65d3e8070d53defbe

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | umm lajj
# Processing Record 2 of Set 15 | avarua
# Processing Record 3 of Set 15 | sinnamary
# Processing Record 4 of Set 15 | graaff-reinet
# Processing Record 5 of Set 15 | kavieng
# Processing Record 6 of Set 15 | sitka
# Processing Record 7 of Set 15 | cayambe
# Processing Record 8 of Set 15 | saint-philippe
# Processing Record 9 of Set 15 | jamestown
# Processing Record 10 of Set 15 | kapaa
# Processing Record 11 of Set 15 | nyzhnya duvanka
# Processing Record 12 of Set 15 | aykhal
# Processing Record 13 of Set 15 | qaanaaq
# Processing Record 14 of Set 15 | isangel
# Processing Record 15 of Set 15 | ongandjera
# Processing Record 16 of Set 15 | santa helena de goias
# Processing Record 17 of Set 15 | tuatapere
# Processing Record 18 of Set 15 | atuona
# Processing Record 19 of Set 15 | east london
# Processing Record 20 of Set 15 | punta arenas
# Processing Record 21 of Set 15 | bethel
# Processing Record 22 of Set 15 | anadyr
# Processing Record 23 of Set 15 | rikitea
# Processing Record 24 of Set 15 | taksimo
# Processing Record 25 of Set 15 | kitimat
# Processing Record 26 of Set 15 | xintai
# Processing Record 27 of Set 15 | airai
# Processing Record 28 of Set 15 | saint-francois
# Processing Record 29 of Set 15 | carnarvon
# Processing Record 30 of Set 15 | thompson
# Processing Record 31 of Set 15 | zheleznodorozhnyy
# Processing Record 32 of Set 15 | merauke
# Processing Record 33 of Set 15 | madimba
# Processing Record 34 of Set 15 | new norfolk
# Processing Record 35 of Set 15 | port lincoln
# Processing Record 36 of Set 15 | vaini
# Processing Record 37 of Set 15 | mizdah
# Processing Record 38 of Set 15 | cidreira
# Processing Record 39 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 40 of Set 15 | bitung
# Processing Record 41 of Set 15 | tateyama
# Processing Record 42 of Set 15 | daru
# Processing Record 43 of Set 15 | shagonar
# Processing Record 44 of Set 15 | riachao das neves
# Processing Record 45 of Set 15 | georgetown
# Processing Record 46 of Set 15 | barra patuca
# Processing Record 47 of Set 15 | albany
# Processing Record 48 of Set 15 | barrow
# Processing Record 49 of Set 15 | bredasdorp
# Processing Record 50 of Set 15 | kamskiye polyany
# Processing Record 1 of Set 16 | upernavik
# Processing Record 2 of Set 16 | ribeira grande
# Processing Record 3 of Set 16 | cherskiy
# Processing Record 4 of Set 16 | ati
# Processing Record 5 of Set 16 | kahului
# Processing Record 6 of Set 16 | marsa matruh
# Processing Record 7 of Set 16 | faanui
# Processing Record 8 of Set 16 | dongsheng
# Processing Record 9 of Set 16 | lebu
# Processing Record 10 of Set 16 | puerto ayora
# Processing Record 11 of Set 16 | tura
# Processing Record 12 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 16 | lusambo
# Processing Record 14 of Set 16 | lagoa
# Processing Record 15 of Set 16 | san cristobal
# Processing Record 16 of Set 16 | port alfred
# Processing Record 17 of Set 16 | ushuaia
# Processing Record 18 of Set 16 | conceicao da barra
# Processing Record 19 of Set 16 | constitucion
# Processing Record 20 of Set 16 | eyl
# Processing Record 21 of Set 16 | ukiah
# Processing Record 22 of Set 16 | severo-kurilsk
# Processing Record 23 of Set 16 | moose factory
# Processing Record 24 of Set 16 | messina
# Processing Record 25 of Set 16 | mataura
# Processing Record 26 of Set 16 | saint george
# Processing Record 27 of Set 16 | sistranda
# Processing Record 28 of Set 16 | le port
# Processing Record 29 of Set 16 | victoria
# Processing Record 30 of Set 16 | mikuni
# Processing Record 31 of Set 16 | busselton
# Processing Record 32 of Set 16 | pingzhuang
# Processing Record 33 of Set 16 | caravelas
# Processing Record 34 of Set 16 | guiyang
# Processing Record 35 of Set 16 | hobart
# Processing Record 36 of Set 16 | bluff
# Processing Record 37 of Set 16 | jujuy
# City not found. Skipping...
# Processing Record 38 of Set 16 | tasiilaq
# Processing Record 39 of Set 16 | mbala
# Processing Record 40 of Set 16 | kamaishi
# Processing Record 41 of Set 16 | bambous virieux
# Processing Record 42 of Set 16 | palestina
# Processing Record 43 of Set 16 | veselynove
# Processing Record 44 of Set 16 | tuktoyaktuk
# Processing Record 45 of Set 16 | butaritari
# Processing Record 46 of Set 16 | mersing
# Processing Record 47 of Set 16 | panaba
# Processing Record 48 of Set 16 | ostrovnoy
# Processing Record 49 of Set 16 | iqaluit
# Processing Record 50 of Set 16 | hermanus
# Processing Record 1 of Set 17 | klaksvik
# Processing Record 2 of Set 17 | beyneu
# Processing Record 3 of Set 17 | vila franca do campo
# Processing Record 4 of Set 17 | katsuura
# Processing Record 5 of Set 17 | gayny
# Processing Record 6 of Set 17 | saquena
# Processing Record 7 of Set 17 | deer lake
# Processing Record 8 of Set 17 | castro
# Processing Record 9 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 17 | katherine
# Processing Record 11 of Set 17 | vostok
# Processing Record 12 of Set 17 | nikolskoye
# Processing Record 13 of Set 17 | hilo
# Processing Record 14 of Set 17 | sorong
# Processing Record 15 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 17 | hithadhoo
# Processing Record 17 of Set 17 | norman wells
# Processing Record 18 of Set 17 | vardo
# Processing Record 19 of Set 17 | honiara
# Processing Record 20 of Set 17 | bathsheba
# Processing Record 21 of Set 17 | macusani
# Processing Record 22 of Set 17 | moyale
# Processing Record 23 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 17 | leshukonskoye
# Processing Record 25 of Set 17 | nome
# Processing Record 26 of Set 17 | hasaki
# Processing Record 27 of Set 17 | solnechnyy
# Processing Record 28 of Set 17 | gazni
# City not found. Skipping...
# Processing Record 29 of Set 17 | grindavik
# Processing Record 30 of Set 17 | amapa
# Processing Record 31 of Set 17 | kavaratti
# Processing Record 32 of Set 17 | southbridge
# Processing Record 33 of Set 17 | lorengau
# Processing Record 34 of Set 17 | pevek
# Processing Record 35 of Set 17 | bridlington
# Processing Record 36 of Set 17 | tommot
# Processing Record 37 of Set 17 | maragogi
# Processing Record 38 of Set 17 | laguna
# Processing Record 39 of Set 17 | calama
# Processing Record 40 of Set 17 | mar del plata
# Processing Record 41 of Set 17 | berzence
# Processing Record 42 of Set 17 | cabedelo
# Processing Record 43 of Set 17 | cape town
# Processing Record 44 of Set 17 | dwarka
# Processing Record 45 of Set 17 | perth
# Processing Record 46 of Set 17 | ewa beach
# Processing Record 47 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 17 | dikson
# Processing Record 49 of Set 17 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 50 of Set 17 | okato
# Processing Record 1 of Set 18 | provideniya
# Processing Record 2 of Set 18 | bantacan
# Processing Record 3 of Set 18 | along
# Processing Record 4 of Set 18 | bakel
# Processing Record 5 of Set 18 | guiratinga
# Processing Record 6 of Set 18 | sobolevo
# Processing Record 7 of Set 18 | coihaique
# Processing Record 8 of Set 18 | kibre mengist
# Processing Record 9 of Set 18 | pisco
# Processing Record 10 of Set 18 | dingle
# Processing Record 11 of Set 18 | ketchikan
# Processing Record 12 of Set 18 | fort nelson
# Processing Record 13 of Set 18 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 18 | broome
# Processing Record 15 of Set 18 | kodiak
# Processing Record 16 of Set 18 | esperance
# Processing Record 17 of Set 18 | zaranj
# Processing Record 18 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 18 | buchanan
# Processing Record 20 of Set 18 | buin
# Processing Record 21 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 18 | tagusao
# Processing Record 23 of Set 18 | bardiyah
# Processing Record 24 of Set 18 | anchorage
# Processing Record 25 of Set 18 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 18 | kyzyl-suu
# Processing Record 27 of Set 18 | palembang
# Processing Record 28 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 18 | minab
# Processing Record 30 of Set 18 | jibuti
# Processing Record 31 of Set 18 | soligalich
# Processing Record 32 of Set 18 | yarega
# Processing Record 33 of Set 18 | baranain
# Processing Record 34 of Set 18 | emerald
# Processing Record 35 of Set 18 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 18 | marawi
# Processing Record 37 of Set 18 | jiaojiang
# Processing Record 38 of Set 18 | bengkulu
# Processing Record 39 of Set 18 | waipawa
# Processing Record 40 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 18 | pacific grove
# Processing Record 42 of Set 18 | galle
# Processing Record 43 of Set 18 | iskateley
# Processing Record 44 of Set 18 | belem de sao francisco
# Processing Record 45 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 18 | cabo san lucas
# Processing Record 47 of Set 18 | aripuana
# Processing Record 48 of Set 18 | vila velha
# Processing Record 49 of Set 18 | sankt valentin
# Processing Record 50 of Set 18 | guerrero negro
# Processing Record 1 of Set 19 | alta
# Processing Record 2 of Set 19 | noumea
# Processing Record 3 of Set 19 | khatanga
# Processing Record 4 of Set 19 | ogulin
# Processing Record 5 of Set 19 | gryazovets
# Processing Record 6 of Set 19 | hofn
# Processing Record 7 of Set 19 | aklavik
# Processing Record 8 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 19 | ilhabela
# Processing Record 10 of Set 19 | mogadishu
# Processing Record 11 of Set 19 | kerki
# City not found. Skipping...
# Processing Record 12 of Set 19 | pokrovsk
# Processing Record 13 of Set 19 | puerto escondido
# Processing Record 14 of Set 19 | yellowknife
# Processing Record 15 of Set 19 | rawah
# Processing Record 16 of Set 19 | port huron
# Processing Record 17 of Set 19 | rey bouba
# Processing Record 18 of Set 19 | montrose
# Processing Record 19 of Set 19 | nanakuli
# Processing Record 20 of Set 19 | san patricio
# Processing Record 21 of Set 19 | churapcha
# Processing Record 22 of Set 19 | opuwo
# Processing Record 23 of Set 19 | bajo baudo
# City not found. Skipping...
# Processing Record 24 of Set 19 | xai-xai
# Processing Record 25 of Set 19 | kununurra
# Processing Record 26 of Set 19 | slonim
# Processing Record 27 of Set 19 | progress
# Processing Record 28 of Set 19 | richards bay
# Processing Record 29 of Set 19 | clyde river
# Processing Record 30 of Set 19 | sao filipe
# Processing Record 31 of Set 19 | manado
# Processing Record 32 of Set 19 | kindersley
# Processing Record 33 of Set 19 | faya
# Processing Record 34 of Set 19 | auki
# Processing Record 35 of Set 19 | nanortalik
# Processing Record 36 of Set 19 | adrar
# Processing Record 37 of Set 19 | kjollefjord
# Processing Record 38 of Set 19 | rafraf
# Processing Record 39 of Set 19 | malanje
# Processing Record 40 of Set 19 | mecca
# Processing Record 41 of Set 19 | olafsvik
# Processing Record 42 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 19 | zhangjiakou
# Processing Record 44 of Set 19 | mirabad
# Processing Record 45 of Set 19 | okha
# Processing Record 46 of Set 19 | sur
# Processing Record 47 of Set 19 | deputatskiy
# Processing Record 48 of Set 19 | bang saphan
# Processing Record 49 of Set 19 | talaya
# Processing Record 50 of Set 19 | hobyo
# Processing Record 1 of Set 20 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 20 | beloha
# Processing Record 3 of Set 20 | chama
# Processing Record 4 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 20 | chokurdakh
# Processing Record 6 of Set 20 | batemans bay
# Processing Record 7 of Set 20 | arraial do cabo
# Processing Record 8 of Set 20 | saint-pierre
# Processing Record 9 of Set 20 | menongue
# Processing Record 10 of Set 20 | rawson
# Processing Record 11 of Set 20 | dawei
# Processing Record 12 of Set 20 | rognan
# Processing Record 13 of Set 20 | imbituba
# Processing Record 14 of Set 20 | mahebourg
# Processing Record 15 of Set 20 | nemuro
# Processing Record 16 of Set 20 | mount gambier
# Processing Record 17 of Set 20 | alyangula
# Processing Record 18 of Set 20 | campo alegre
# Processing Record 19 of Set 20 | komsomolskiy
# Processing Record 20 of Set 20 | shubarshi
# Processing Record 21 of Set 20 | ternate
# Processing Record 22 of Set 20 | codrington
# Processing Record 23 of Set 20 | mao
# Processing Record 24 of Set 20 | aranos
# Processing Record 25 of Set 20 | souillac
# Processing Record 26 of Set 20 | bac lieu
# Processing Record 27 of Set 20 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 20 | kamenskiy
# Processing Record 29 of Set 20 | husavik
# Processing Record 30 of Set 20 | umm kaddadah
# Processing Record 31 of Set 20 | les cayes
# Processing Record 32 of Set 20 | narsaq
# Processing Record 33 of Set 20 | morondava
# Processing Record 34 of Set 20 | saint-joseph
# Processing Record 35 of Set 20 | touros
# Processing Record 36 of Set 20 | ampanihy
# Processing Record 37 of Set 20 | gurupi
# Processing Record 38 of Set 20 | gamba
# Processing Record 39 of Set 20 | bilma
# Processing Record 40 of Set 20 | altay
# Processing Record 41 of Set 20 | lasa
# Processing Record 42 of Set 20 | borovskoy
# Processing Record 43 of Set 20 | progreso
# Processing Record 44 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 20 | tezu
# Processing Record 46 of Set 20 | bezhetsk
# Processing Record 47 of Set 20 | yaan
# Processing Record 48 of Set 20 | ucluelet
# Processing Record 49 of Set 20 | melito di porto salvo
# Processing Record 50 of Set 20 | camana
# Processing Record 1 of Set 21 | vao
# Processing Record 2 of Set 21 | edd
# Processing Record 3 of Set 21 | yumen
# Processing Record 4 of Set 21 | darhan
# Processing Record 5 of Set 21 | livingstone
# Processing Record 6 of Set 21 | belmonte
# Processing Record 7 of Set 21 | kapuskasing
# Processing Record 8 of Set 21 | qiqihar
# Processing Record 9 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 21 | bonito
# Processing Record 11 of Set 21 | naze
# Processing Record 12 of Set 21 | twentynine palms
# Processing Record 13 of Set 21 | labuhan
# Processing Record 14 of Set 21 | turukhansk
# Processing Record 15 of Set 21 | aksu
# Processing Record 16 of Set 21 | baiao
# Processing Record 17 of Set 21 | log
# Processing Record 18 of Set 21 | chitipa
# Processing Record 19 of Set 21 | torbay
# Processing Record 20 of Set 21 | port elizabeth
# Processing Record 21 of Set 21 | filadelfia
# Processing Record 22 of Set 21 | itoman
# Processing Record 23 of Set 21 | champerico
# Processing Record 24 of Set 21 | leningradskiy
# Processing Record 25 of Set 21 | sabha
# Processing Record 26 of Set 21 | bowen
# Processing Record 27 of Set 21 | george
# Processing Record 28 of Set 21 | skiros
# City not found. Skipping...
# Processing Record 29 of Set 21 | vila
# Processing Record 30 of Set 21 | beringovskiy
# Processing Record 31 of Set 21 | sao felix do xingu
# Processing Record 32 of Set 21 | dustlik
# Processing Record 33 of Set 21 | marabba
# Processing Record 34 of Set 21 | ust-nera
# Processing Record 35 of Set 21 | vanimo
# Processing Record 36 of Set 21 | ruidoso
# Processing Record 37 of Set 21 | saldanha
# Processing Record 38 of Set 21 | erenhot
# Processing Record 39 of Set 21 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 21 | tombouctou
# Processing Record 41 of Set 21 | talnakh
# Processing Record 42 of Set 21 | fortuna
# Processing Record 43 of Set 21 | celestun
# Processing Record 44 of Set 21 | lavrentiya
# Processing Record 45 of Set 21 | jinxiang
# Processing Record 46 of Set 21 | partyzany
# Processing Record 47 of Set 21 | luderitz
# Processing Record 48 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 21 | saskylakh
# Processing Record 50 of Set 21 | yuci
# Processing Record 1 of Set 22 | xining
# Processing Record 2 of Set 22 | longyearbyen
# Processing Record 3 of Set 22 | tarauaca
# Processing Record 4 of Set 22 | tocopilla
# Processing Record 5 of Set 22 | bonavista
# Processing Record 6 of Set 22 | nola
# Processing Record 7 of Set 22 | voineasa
# Processing Record 8 of Set 22 | lima
# Processing Record 9 of Set 22 | tupiza
# Processing Record 10 of Set 22 | nikolsk
# Processing Record 11 of Set 22 | chuy
# Processing Record 12 of Set 22 | camacha
# Processing Record 13 of Set 22 | kisangani
# Processing Record 14 of Set 22 | havre-saint-pierre
# Processing Record 15 of Set 22 | pedernales
# Processing Record 16 of Set 22 | conceicao do araguaia
# Processing Record 17 of Set 22 | ancud
# Processing Record 18 of Set 22 | warrington
# Processing Record 19 of Set 22 | winnipeg
# Processing Record 20 of Set 22 | lompoc
# Processing Record 21 of Set 22 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 22 | mayumba
# Processing Record 23 of Set 22 | half moon bay
# Processing Record 24 of Set 22 | ca mau
# Processing Record 25 of Set 22 | ponta do sol
# Processing Record 26 of Set 22 | victoria point
# Processing Record 27 of Set 22 | mpulungu
# Processing Record 28 of Set 22 | nador
# Processing Record 29 of Set 22 | lata
# Processing Record 30 of Set 22 | kotri
# Processing Record 31 of Set 22 | alice springs
# Processing Record 32 of Set 22 | sao joao da barra
# Processing Record 33 of Set 22 | yulara
# Processing Record 34 of Set 22 | ho
# City not found. Skipping...
# Processing Record 35 of Set 22 | nishihara
# Processing Record 36 of Set 22 | san quintin
# Processing Record 37 of Set 22 | ahipara
# Processing Record 38 of Set 22 | meulaboh
# Processing Record 39 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 22 | maracas
# Processing Record 41 of Set 22 | mata
# Processing Record 42 of Set 22 | mackenzie
# Processing Record 43 of Set 22 | kangaatsiaq
# Processing Record 44 of Set 22 | yar-sale
# Processing Record 45 of Set 22 | geraldton
# Processing Record 46 of Set 22 | novorzhev
# Processing Record 47 of Set 22 | markova
# Processing Record 48 of Set 22 | sao domingos
# Processing Record 49 of Set 22 | concordia
# Processing Record 50 of Set 22 | neiafu
# Processing Record 1 of Set 23 | la ronge
# Processing Record 2 of Set 23 | port hedland
# Processing Record 3 of Set 23 | kenai
# Processing Record 4 of Set 23 | kodinar
# Processing Record 5 of Set 23 | hualmay
# Processing Record 6 of Set 23 | upington
# Processing Record 7 of Set 23 | tiksi
# Processing Record 8 of Set 23 | kulhudhuffushi
# Processing Record 9 of Set 23 | fairlie
# Processing Record 10 of Set 23 | hamilton
# Processing Record 11 of Set 23 | requena
# Processing Record 12 of Set 23 | kaitangata
# Processing Record 13 of Set 23 | matadi
# Processing Record 14 of Set 23 | chandbali
# Processing Record 15 of Set 23 | khovu-aksy
# Processing Record 16 of Set 23 | weatherford
# Processing Record 17 of Set 23 | brownsville
# Processing Record 18 of Set 23 | san jose
# Processing Record 19 of Set 23 | sorland
# Processing Record 20 of Set 23 | pangai
# Processing Record 21 of Set 23 | nakambala
# Processing Record 22 of Set 23 | sandnessjoen
# Processing Record 23 of Set 23 | ponca city
# Processing Record 24 of Set 23 | taoudenni
# Processing Record 25 of Set 23 | college
# Processing Record 26 of Set 23 | seoul
# Processing Record 27 of Set 23 | aljezur
# Processing Record 28 of Set 23 | saint-augustin
# Processing Record 29 of Set 23 | te anau
# Processing Record 30 of Set 23 | korla
# Processing Record 31 of Set 23 | otane
# Processing Record 32 of Set 23 | nagorsk
# Processing Record 33 of Set 23 | kovernino
# Processing Record 34 of Set 23 | guarda
# Processing Record 35 of Set 23 | port moresby
# Processing Record 36 of Set 23 | gat
# Processing Record 37 of Set 23 | pirgos
# Processing Record 38 of Set 23 | neuquen
# Processing Record 39 of Set 23 | karpathos
# Processing Record 40 of Set 23 | chinsali
# Processing Record 41 of Set 23 | andros town
# Processing Record 42 of Set 23 | gus-zheleznyy
# Processing Record 43 of Set 23 | lebanon
# Processing Record 44 of Set 23 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 23 | damavand
# Processing Record 46 of Set 23 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 23 | yaroslavskiy
# Processing Record 48 of Set 23 | redlands
# Processing Record 49 of Set 23 | falkoping
# City not found. Skipping...
# Processing Record 50 of Set 23 | margate
# Processing Record 1 of Set 24 | mehamn
# Processing Record 2 of Set 24 | lakes entrance
# Processing Record 3 of Set 24 | siguiri
# Processing Record 4 of Set 24 | lebedinyy
# Processing Record 5 of Set 24 | porto
# Processing Record 6 of Set 24 | hongjiang
# Processing Record 7 of Set 24 | cayenne
# Processing Record 8 of Set 24 | casa nova
# Processing Record 9 of Set 24 | hanover
# Processing Record 10 of Set 24 | caluquembe
# Processing Record 11 of Set 24 | dicabisagan
# Processing Record 12 of Set 24 | bay roberts
# Processing Record 13 of Set 24 | lokosovo
# Processing Record 14 of Set 24 | asau
# Processing Record 15 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 24 | bindi
# Processing Record 17 of Set 24 | chau doc
# Processing Record 18 of Set 24 | petropavl
# Processing Record 19 of Set 24 | urumqi
# Processing Record 20 of Set 24 | pilar
# Processing Record 21 of Set 24 | napier
# Processing Record 22 of Set 24 | nuevo progreso
# Processing Record 23 of Set 24 | ouegoa
# Processing Record 24 of Set 24 | chlorakas
# Processing Record 25 of Set 24 | kibala
# Processing Record 26 of Set 24 | belen
# Processing Record 27 of Set 24 | henties bay
# Processing Record 28 of Set 24 | yuzhnyy
# Processing Record 29 of Set 24 | flin flon
# Processing Record 30 of Set 24 | baykit
# Processing Record 31 of Set 24 | vilyuysk
# Processing Record 32 of Set 24 | tornio
# Processing Record 33 of Set 24 | lively
# Processing Record 34 of Set 24 | asfi
# Processing Record 35 of Set 24 | sambava
# Processing Record 36 of Set 24 | asuncion
# Processing Record 37 of Set 24 | kwinana
# Processing Record 38 of Set 24 | kamenka
# Processing Record 39 of Set 24 | divnomorskoye
# Processing Record 40 of Set 24 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 24 | victor harbor
# Processing Record 42 of Set 24 | fengkou
# Processing Record 43 of Set 24 | alberton
# Processing Record 44 of Set 24 | atchison
# Processing Record 45 of Set 24 | jishou
# Processing Record 46 of Set 24 | necochea
# Processing Record 47 of Set 24 | the valley
# Processing Record 48 of Set 24 | pakenham
# Processing Record 49 of Set 24 | beawar
# Processing Record 50 of Set 24 | bouafle
# Processing Record 1 of Set 25 | biltine
# Processing Record 2 of Set 25 | cajabamba
# Processing Record 3 of Set 25 | bereda
# Processing Record 4 of Set 25 | awjilah
# Processing Record 5 of Set 25 | englewood
# Processing Record 6 of Set 25 | shimoda
# Processing Record 7 of Set 25 | haines junction
# Processing Record 8 of Set 25 | melfort
# Processing Record 9 of Set 25 | flinders
# Processing Record 10 of Set 25 | moree
# Processing Record 11 of Set 25 | yuza
# Processing Record 12 of Set 25 | vuktyl
# Processing Record 13 of Set 25 | abu dhabi
# Processing Record 14 of Set 25 | maloshuyka
# City not found. Skipping...
# Processing Record 15 of Set 25 | surt
# Processing Record 16 of Set 25 | taloqan
# Processing Record 17 of Set 25 | istanbul
# Processing Record 18 of Set 25 | chumikan
# Processing Record 19 of Set 25 | manakara
# Processing Record 20 of Set 25 | sabang
# Processing Record 21 of Set 25 | kruisfontein
# Processing Record 22 of Set 25 | alpena
# Processing Record 23 of Set 25 | waingapu
# Processing Record 24 of Set 25 | agadez
# Processing Record 25 of Set 25 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 25 | peniche
# Processing Record 27 of Set 25 | suicheng
# Processing Record 28 of Set 25 | tilichiki
# Processing Record 29 of Set 25 | tambul
# City not found. Skipping...
# Processing Record 30 of Set 25 | glens falls
# Processing Record 31 of Set 25 | yamethin
# Processing Record 32 of Set 25 | temyasovo
# Processing Record 33 of Set 25 | padang
# Processing Record 34 of Set 25 | tromso
# Processing Record 35 of Set 25 | kempsey
# Processing Record 36 of Set 25 | ayan
# Processing Record 37 of Set 25 | shizunai
# Processing Record 38 of Set 25 | baruun-urt
# Processing Record 39 of Set 25 | coruripe
# Processing Record 40 of Set 25 | buala
# Processing Record 41 of Set 25 | carutapera
# Processing Record 42 of Set 25 | liliani
# Processing Record 43 of Set 25 | vanavara
# Processing Record 44 of Set 25 | krasnystaw
# Processing Record 45 of Set 25 | dickinson
# Processing Record 46 of Set 25 | mnogovershinnyy
# Processing Record 47 of Set 25 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 25 | kiama
# Processing Record 49 of Set 25 | butler
# Processing Record 50 of Set 25 | christiana
# Processing Record 1 of Set 26 | sechura
# Processing Record 2 of Set 26 | peleduy
# Processing Record 3 of Set 26 | shelburne
# Processing Record 4 of Set 26 | olinda
# Processing Record 5 of Set 26 | salalah
# Processing Record 6 of Set 26 | hervey bay
# Processing Record 7 of Set 26 | gizo
# Processing Record 8 of Set 26 | monastyrshchina
# Processing Record 9 of Set 26 | biak
# Processing Record 10 of Set 26 | omboue
# Processing Record 11 of Set 26 | jabinyanah
# Processing Record 12 of Set 26 | cururupu
# Processing Record 13 of Set 26 | tupelo
# Processing Record 14 of Set 26 | lumphat
# Processing Record 15 of Set 26 | adrasmon
# Processing Record 16 of Set 26 | srednekolymsk
# Processing Record 17 of Set 26 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 26 | joshimath
# Processing Record 19 of Set 26 | nizip
# Processing Record 20 of Set 26 | bokspits
# City not found. Skipping...
# Processing Record 21 of Set 26 | mardin
# Processing Record 22 of Set 26 | birjand
# Processing Record 23 of Set 26 | saint simons
# Processing Record 24 of Set 26 | nouna
# Processing Record 25 of Set 26 | palm city
# Processing Record 26 of Set 26 | kargasok
# Processing Record 27 of Set 26 | volodarskiy
# Processing Record 28 of Set 26 | ballina
# Processing Record 29 of Set 26 | skibbereen
# Processing Record 30 of Set 26 | zalesovo
# Processing Record 31 of Set 26 | avera
# Processing Record 32 of Set 26 | tulsipur
# Processing Record 33 of Set 26 | mariental
# Processing Record 34 of Set 26 | maroua
# Processing Record 35 of Set 26 | huanuco
# Processing Record 36 of Set 26 | rocha
# Processing Record 37 of Set 26 | labuan
# Processing Record 38 of Set 26 | kamenolomni
# Processing Record 39 of Set 26 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 26 | honningsvag
# Processing Record 41 of Set 26 | eldorado
# Processing Record 42 of Set 26 | bom jesus
# Processing Record 43 of Set 26 | calvinia
# Processing Record 44 of Set 26 | puerto del rosario
# Processing Record 45 of Set 26 | benguela
# Processing Record 46 of Set 26 | kirakira
# Processing Record 47 of Set 26 | bumba
# Processing Record 48 of Set 26 | barra do garcas
# Processing Record 49 of Set 26 | spirit river
# Processing Record 50 of Set 26 | sogdiondon
# City not found. Skipping...
# Processing Record 1 of Set 27 | springbok
# Processing Record 2 of Set 27 | katobu
# Processing Record 3 of Set 27 | amaigbo
# Processing Record 4 of Set 27 | san rafael
# Processing Record 5 of Set 27 | glenn dale
# Processing Record 6 of Set 27 | mangan
# Processing Record 7 of Set 27 | port hardy
# Processing Record 8 of Set 27 | lysyye gory
# Processing Record 9 of Set 27 | bo rai
# Processing Record 10 of Set 27 | havelock
# Processing Record 11 of Set 27 | ulladulla
# Processing Record 12 of Set 27 | kimbe
# Processing Record 13 of Set 27 | new richmond
# Processing Record 14 of Set 27 | briceno
# Processing Record 15 of Set 27 | walcourt
# Processing Record 16 of Set 27 | manjacaze
# Processing Record 17 of Set 27 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 27 | tucupita
# Processing Record 19 of Set 27 | wanaka
# Processing Record 20 of Set 27 | sangar
# Processing Record 21 of Set 27 | ciras
# City not found. Skipping...
# Processing Record 22 of Set 27 | saurimo
# Processing Record 23 of Set 27 | mullaitivu
# City not found. Skipping...
# Processing Record 24 of Set 27 | niquelandia
# Processing Record 25 of Set 27 | thinadhoo
# Processing Record 26 of Set 27 | ramban
# Processing Record 27 of Set 27 | pervomaysk
# Processing Record 28 of Set 27 | paamiut
# Processing Record 29 of Set 27 | westport
# Processing Record 30 of Set 27 | durazno
# Processing Record 31 of Set 27 | kudahuvadhoo
# Processing Record 32 of Set 27 | paragominas
# Processing Record 33 of Set 27 | orbetello
# Processing Record 34 of Set 27 | tynda
# Processing Record 35 of Set 27 | bozoum
# Processing Record 36 of Set 27 | matara
# Processing Record 37 of Set 27 | tabou
# Processing Record 38 of Set 27 | aquiraz
# Processing Record 39 of Set 27 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 27 | worland
# Processing Record 41 of Set 27 | guozhen
# Processing Record 42 of Set 27 | namibe
# Processing Record 43 of Set 27 | praya
# Processing Record 44 of Set 27 | kholodnyy
# Processing Record 45 of Set 27 | baiquan
# Processing Record 46 of Set 27 | chilmari
# Processing Record 47 of Set 27 | kholmogory
# Processing Record 48 of Set 27 | valparaiso
# Processing Record 49 of Set 27 | nyuksenitsa
# Processing Record 50 of Set 27 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 28 | abengourou
# Processing Record 2 of Set 28 | boa vista
# Processing Record 3 of Set 28 | kiunga
# Processing Record 4 of Set 28 | sembakung
# Processing Record 5 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 28 | murray bridge
# Processing Record 7 of Set 28 | kartaly
# Processing Record 8 of Set 28 | plainview
# Processing Record 9 of Set 28 | groningen
# Processing Record 10 of Set 28 | ekhabi
# Processing Record 11 of Set 28 | alofi
# Processing Record 12 of Set 28 | williams lake
# Processing Record 13 of Set 28 | banjar
# Processing Record 14 of Set 28 | rio grande
# Processing Record 15 of Set 28 | tomatlan
# Processing Record 16 of Set 28 | umba
# Processing Record 17 of Set 28 | santa maria
# Processing Record 18 of Set 28 | maceio
# Processing Record 19 of Set 28 | schertz
# Processing Record 20 of Set 28 | hutchinson
# Processing Record 21 of Set 28 | akdepe
# Processing Record 22 of Set 28 | bilibino
# Processing Record 23 of Set 28 | didi lilo
# Processing Record 24 of Set 28 | ahuimanu
# Processing Record 25 of Set 28 | moussoro
# Processing Record 26 of Set 28 | pontes e lacerda
# Processing Record 27 of Set 28 | karratha
# Processing Record 28 of Set 28 | porto velho
# Processing Record 29 of Set 28 | coari
# Processing Record 30 of Set 28 | aswan
# Processing Record 31 of Set 28 | mega
# Processing Record 32 of Set 28 | bhadrachalam
# Processing Record 33 of Set 28 | nevel
# Processing Record 34 of Set 28 | ilulissat
# Processing Record 35 of Set 28 | khuzhir
# Processing Record 36 of Set 28 | karwar
# Processing Record 37 of Set 28 | omis
# Processing Record 38 of Set 28 | williamsburg
# Processing Record 39 of Set 28 | clearwater
# Processing Record 40 of Set 28 | veraval
# Processing Record 41 of Set 28 | temaraia
# City not found. Skipping...
# Processing Record 42 of Set 28 | udachnyy
# Processing Record 43 of Set 28 | karymskoye
# Processing Record 44 of Set 28 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 28 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 28 | wageningen
# Processing Record 47 of Set 28 | quang ngai
# Processing Record 48 of Set 28 | ojinaga
# Processing Record 49 of Set 28 | kachikau
# City not found. Skipping...
# Processing Record 50 of Set 28 | hendijan
# City not found. Skipping...
# Processing Record 1 of Set 29 | muros
# Processing Record 2 of Set 29 | khasan
# Processing Record 3 of Set 29 | imeni poliny osipenko
# Processing Record 4 of Set 29 | puerto el triunfo
# Processing Record 5 of Set 29 | kaseda
# Processing Record 6 of Set 29 | tigre
# Processing Record 7 of Set 29 | jenbach
# Processing Record 8 of Set 29 | bairiki
# Processing Record 9 of Set 29 | deshna
# City not found. Skipping...
# Processing Record 10 of Set 29 | nouadhibou
# Processing Record 11 of Set 29 | el badari
# City not found. Skipping...
# Processing Record 12 of Set 29 | gondar
# Processing Record 13 of Set 29 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 29 | kalmunai
# Processing Record 15 of Set 29 | mokshan
# Processing Record 16 of Set 29 | poltavka
# Processing Record 17 of Set 29 | glenwood springs
# Processing Record 18 of Set 29 | tecoanapa
# Processing Record 19 of Set 29 | kailua
# Processing Record 20 of Set 29 | mannarakkat
# Processing Record 21 of Set 29 | north bend
# Processing Record 22 of Set 29 | saint anthony
# Processing Record 23 of Set 29 | ipoti
# Processing Record 24 of Set 29 | turbat
# Processing Record 25 of Set 29 | yuli
# Processing Record 26 of Set 29 | ormara
# Processing Record 27 of Set 29 | zhezkazgan
# Processing Record 28 of Set 29 | dunedin
# Processing Record 29 of Set 29 | pathein
# Processing Record 30 of Set 29 | belaya gora
# Processing Record 31 of Set 29 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 29 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 29 | erzincan
# Processing Record 34 of Set 29 | marfino
# Processing Record 35 of Set 29 | tala
# Processing Record 36 of Set 29 | toftir
# City not found. Skipping...
# Processing Record 37 of Set 29 | inhambane
# Processing Record 38 of Set 29 | thunder bay
# Processing Record 39 of Set 29 | petrovsk-zabaykalskiy
# Processing Record 40 of Set 29 | nizhniy kuranakh
# Processing Record 41 of Set 29 | mulege
# Processing Record 42 of Set 29 | muroto
# Processing Record 43 of Set 29 | gangotri
# City not found. Skipping...
# Processing Record 44 of Set 29 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 29 | puro
# Processing Record 46 of Set 29 | manaus
# Processing Record 47 of Set 29 | pandan
# Processing Record 48 of Set 29 | qaqortoq
# Processing Record 49 of Set 29 | roald
# Processing Record 50 of Set 29 | bismarck
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Umm Lajj      SA  25.0213   37.2685     83.98        52           0
# 1          Avarua      CK -21.2078 -159.7750     77.05        69           0
# 2       Sinnamary      GF   5.3833  -52.9500     77.97        87          65
# 3   Graaff-Reinet      ZA -32.2522   24.5308     33.15        76           0
# 4         Kavieng      PG  -2.5744  150.7967     84.96        72         100
# 5           Sitka      US  57.0531 -135.3300     57.09        82          90
# 6         Cayambe      EC   0.0500  -78.1333     49.26        84         100
# 7  Saint-Philippe      RE -21.3585   55.7679     65.79        71          35
# 8       Jamestown      US  42.0970  -79.2353     65.84        69           1
# 9           Kapaa      US  22.0752 -159.3190     82.38        83          90
#
#    Wind Speed Current Description
# 0        3.11           clear sky
# 1       11.50           clear sky
# 2       12.84       broken clouds
# 3        4.52           clear sky
# 4       14.36     overcast clouds
# 5       10.36          light rain
# 6        5.39     overcast clouds
# 7        5.48    scattered clouds
# 8       10.36           clear sky
# 9        1.99       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
